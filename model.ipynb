# %% [markdown]
# <a href="https://colab.research.google.com/github/chalghoumihangout-afk/Chalghoumi/blob/main/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =======================
# Exemple modèle Colab
# =======================

from sklearn.linear_model import LinearRegression
import numpy as np
import joblib

# Jeu de données simple
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8,10])

# Entrainement
model = LinearRegression()
model.fit(X, y)

# Sauvegarde du modèle
joblib.dump(model, "model.pkl")

print("Modèle sauvegardé sous model.pkl")
# Out:
# Modèle sauvegardé sous model.pkl
